# %%
import re
import pandas as pd

# %%
text = """

-----------------------------------------------------------------------------------
v1                                      Able to take active role in political group
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  actrolg, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  713/39,325

              examples:  0     Not at all able
                         2     
                         5     
                         7     

-----------------------------------------------------------------------------------
v2                      Feeling of safety of walking alone in local area after dark
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  aesfdrk

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  396/39,325

            tabulation:  Freq.   Numeric  Label
                        11,483         1  Very safe
                        19,872         2  Safe
                         6,283         3  Unsafe
                         1,291         4  Very unsafe
                            17        .a  Refusal
                           369        .b  Don't know
                            10        .c  No answer

-----------------------------------------------------------------------------------
v3                                                    Age of respondent, calculated
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  agea, but 90 nonmissing values are not labeled

                 range:  [14,114]                     units:  1
         unique values:  90                       missing .:  0/39,325
       unique mv codes:  1                       missing .*:  97/39,325

              examples:  31    
                         44    
                         55    
                         67    

-----------------------------------------------------------------------------------
v4   First ancestry, European Standard Classification of Cultural and Ethnic Groups
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  anctry1

                 range:  [10000,444444]               units:  1
         unique values:  184                      missing .:  0/39,325
       unique mv codes:  3                       missing .*:  250/39,325

              examples:  11050 French nfs
                         12010 Danish nfs
                         13071 Andalusian
                         15060 Lithuanian nfs

-----------------------------------------------------------------------------------
v5                                     Second ancestry, European Standard
                                       Classification of Cultural and Ethnic Groups
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  anctry2

                 range:  [10000,444444]               units:  1
         unique values:  174                      missing .:  0/39,325
       unique mv codes:  4                       missing .*:  27,208/39,325

              examples:  15020 Czech nfs
                         .a    No second ancestry
                         .a    No second ancestry
                         .a    No second ancestry

-----------------------------------------------------------------------------------
v6              Improve knowledge/skills: course/lecture/conference, last 12 months
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  atncrse

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  238/39,325

            tabulation:  Freq.   Numeric  Label
                        12,152         1  Yes
                        26,935         2  No
                            37        .a  Refusal
                            92        .b  Don't know
                           109        .c  No answer

-----------------------------------------------------------------------------------
v7                          Worn or displayed campaign badge/sticker last 12 months
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  badge

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  88/39,325

            tabulation:  Freq.   Numeric  Label
                         3,400         1  Yes
                        35,837         2  No
                             6        .a  Refusal
                            73        .b  Don't know
                             9        .c  No answer

-----------------------------------------------------------------------------------
v8                                        Boycotted certain products last 12 months
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  bctprd

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  180/39,325

            tabulation:  Freq.   Numeric  Label
                         7,625         1  Yes
                        31,520         2  No
                             7        .a  Refusal
                           166        .b  Don't know
                             7        .c  No answer

-----------------------------------------------------------------------------------
v9                                       Belong to minority ethnic group in country
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  blgetmg

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  515/39,325

            tabulation:  Freq.   Numeric  Label
                         2,510         1  Yes
                        36,300         2  No
                            11        .a  Refusal
                           430        .b  Don't know
                            74        .c  No answer

-----------------------------------------------------------------------------------
v10                                                                 Born in country
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  brncntr

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  10/39,325

            tabulation:  Freq.   Numeric  Label
                        34,874         1  Yes
                         4,441         2  No
                             3        .a  Refusal
                             2        .b  Don't know
                             5        .c  No answer

-----------------------------------------------------------------------------------
v11                                           Ever had children living in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  chldhhe

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  14,210/39,325

            tabulation:  Freq.   Numeric  Label
                        13,080         1  Yes
                        12,035         2  No
                        13,978        .a  Not applicable
                            47        .b  Refusal
                            74        .c  Don't know
                           111        .d  No answer

-----------------------------------------------------------------------------------
v12                                                  Children living at home or not
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  chldhm

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  1                       missing .*:  5/39,325

            tabulation:  Freq.   Numeric  Label
                        13,988         1  Respondent lives with children
                                          at household grid
                        25,332         2  Does not
                             5        .a  Not available

-----------------------------------------------------------------------------------
v13                                        Could not get going, how often past week
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  cldgng

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  297/39,325

            tabulation:  Freq.   Numeric  Label
                        21,619         1  None or almost none of the time
                        14,127         2  Some of the time
                         2,351         3  Most of the time
                           931         4  All or almost all of the time
                            48        .a  Refusal
                           217        .b  Don't know
                            32        .c  No answer

-----------------------------------------------------------------------------------
v14                        Feel closer to a particular party than all other parties
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  clsprty

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  810/39,325

            tabulation:  Freq.   Numeric  Label
                        19,642         1  Yes
                        18,873         2  No
                           130        .a  Refusal
                           668        .b  Don't know
                            12        .c  No answer

-----------------------------------------------------------------------------------
v15                                Doing last 7 days: community or military service
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  cmsrv

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,257         0  Not marked
                            68         1  Marked

-----------------------------------------------------------------------------------
v16                        Partner doing last 7 days: community or military service
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  cmsrvp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,315         0  Not marked
                            10         1  Marked

-----------------------------------------------------------------------------------
v17                                                                Country of birth
-----------------------------------------------------------------------------------

                  type:  string (str2)

         unique values:  172                      missing "":  0/39,325

              examples:  "66"
                         "66"
                         "66"
                         "66"

-----------------------------------------------------------------------------------
v18                      Contacted politician or government official last 12 months
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  contplt

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  82/39,325

            tabulation:  Freq.   Numeric  Label
                         6,292         1  Yes
                        32,951         2  No
                            15        .a  Refusal
                            63        .b  Don't know
                             4        .c  No answer

-----------------------------------------------------------------------------------
v19                             Confident in own ability to participate in politics
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  cptppol, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  659/39,325

              examples:  1     
                         3     
                         5     
                         7     

-----------------------------------------------------------------------------------
v20                                                                          Region
-----------------------------------------------------------------------------------

                  type:  string (str5)

         unique values:  251                      missing "":  0/39,325

              examples:  "DE3"
                         "FI196"
                         "IL"
                         "PL12"

-----------------------------------------------------------------------------------
v21          Respondent or household member victim of burglary/assault last 5 years
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  crmvct

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  99/39,325

            tabulation:  Freq.   Numeric  Label
                         6,666         1  Yes
                        32,560         2  No
                             9        .a  Refusal
                            85        .b  Don't know
                             5        .c  No answer

-----------------------------------------------------------------------------------
v22                                                   Control paid work last 7 days
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  crpdwk

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  20,646/39,325

            tabulation:  Freq.   Numeric  Label
                           767         1  Yes
                        17,912         2  No
                        20,584        .a  Not applicable
                            21        .b  Refusal
                            23        .c  Don't know
                            18        .d  No answer

-----------------------------------------------------------------------------------
v23                                          Partner, control paid work last 7 days
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  crpdwkp

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  30,316/39,325

            tabulation:  Freq.   Numeric  Label
                           328         1  Yes
                         8,681         2  No
                        30,024        .a  Not applicable
                            29        .b  Refusal
                            35        .c  Don't know
                           228        .d  No answer

-----------------------------------------------------------------------------------
v24                                                              Citizen of country
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ctzcntr

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  22/39,325

            tabulation:  Freq.   Numeric  Label
                        37,266         1  Yes
                         2,037         2  No
                             5        .a  Refusal
                            12        .b  Don't know
                             5        .c  No answer

-----------------------------------------------------------------------------------
v25                                                                     Citizenship
-----------------------------------------------------------------------------------

                  type:  string (str2)

         unique values:  130                      missing "":  0/39,325

              examples:  "66"
                         "66"
                         "66"
                         "66"

-----------------------------------------------------------------------------------
v26                                                   Doing last 7 days: don't know
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dngdk

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,305         0  Not marked
                            20         1  Marked

-----------------------------------------------------------------------------------
v27                                           Partner doing last 7 days: don't know
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dngdkp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,278         0  Not marked
                            47         1  Marked

-----------------------------------------------------------------------------------
v28                                                    Doing last 7 days: no answer
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dngna

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,293         0  Not marked
                            32         1  Marked

-----------------------------------------------------------------------------------
v29                                            Partner doing last 7 days: no answer
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dngnap

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,135         0  Not marked
                           190         1  Marked

-----------------------------------------------------------------------------------
v30                                       Partner doing last 7 days: not applicable
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dngnapp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        23,304         0  Not marked
                        16,021         1  Marked

-----------------------------------------------------------------------------------
v31                                                        Doing last 7 days: other
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dngoth

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,705         0  Not marked
                           620         1  Marked

-----------------------------------------------------------------------------------
v32                                                Partner doing last 7 days: other
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dngothp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,088         0  Not marked
                           237         1  Marked

-----------------------------------------------------------------------------------
v33                                                      Doing last 7 days: refusal
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dngref

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,294         0  Not marked
                            31         1  Marked

-----------------------------------------------------------------------------------
v34                                              Partner doing last 7 days: refusal
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dngrefp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,267         0  Not marked
                            58         1  Marked

-----------------------------------------------------------------------------------
v35                                              Domicile, respondent's description
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  domicil

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  88/39,325

            tabulation:  Freq.   Numeric  Label
                         8,325         1  A big city
                         4,622         2  Suburbs or outskirts of big city
                        12,668         3  Town or small city
                        11,130         4  Country village
                         2,492         5  Farm or home in countryside
                            11        .a  Refusal
                            63        .b  Don't know
                            14        .c  No answer

-----------------------------------------------------------------------------------
v36                                 Doing last 7 days: permanently sick or disabled
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dsbld

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        37,967         0  Not marked
                         1,358         1  Marked

-----------------------------------------------------------------------------------
v37                         Partner doing last 7 days: permanently sick or disabled
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dsbldp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,757         0  Not marked
                           568         1  Marked

-----------------------------------------------------------------------------------
v38                                       Discrimination of respondent's group: age
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrage

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,809         0  Not marked
                           516         1  Marked

-----------------------------------------------------------------------------------
v39                                Discrimination of respondent's group: don't know
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrdk

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,291         0  Not marked
                            34         1  Marked

-----------------------------------------------------------------------------------
v40                                Discrimination of respondent's group: disability
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrdsb

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,041         0  Not marked
                           284         1  Marked

-----------------------------------------------------------------------------------
v41                              Discrimination of respondent's group: ethnic group
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscretn

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,936         0  Not marked
                           389         1  Marked

-----------------------------------------------------------------------------------
v42                                    Discrimination of respondent's group: gender
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrgnd

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,936         0  Not marked
                           389         1  Marked

-----------------------------------------------------------------------------------
v43                         Member of a group discriminated against in this country
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrgrp

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  336/39,325

            tabulation:  Freq.   Numeric  Label
                         3,201         1  Yes
                        35,788         2  No
                            18        .a  Refusal
                           308        .b  Don't know
                            10        .c  No answer

-----------------------------------------------------------------------------------
v44                                  Discrimination of respondent's group: language
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrlng

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,858         0  Not marked
                           467         1  Marked

-----------------------------------------------------------------------------------
v45                                 Discrimination of respondent's group: no answer
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrna

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,319         0  Not marked
                             6         1  Marked

-----------------------------------------------------------------------------------
v46                            Discrimination of respondent's group: not applicable
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrnap

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                         3,211         0  Not marked
                        36,114         1  Marked

-----------------------------------------------------------------------------------
v47                               Discrimination of respondent's group: nationality
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrntn

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,556         0  Not marked
                           769         1  Marked

-----------------------------------------------------------------------------------
v48                             Discrimination of respondent's group: other grounds
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscroth

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,610         0  Not marked
                           715         1  Marked

-----------------------------------------------------------------------------------
v49                            Discrimination of respondent's group: colour or race
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrrce

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,795         0  Not marked
                           530         1  Marked

-----------------------------------------------------------------------------------
v50                                   Discrimination of respondent's group: refusal
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrref

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,317         0  Not marked
                             8         1  Marked

-----------------------------------------------------------------------------------
v51                                  Discrimination of respondent's group: religion
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrrlg

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,658         0  Not marked
                           667         1  Marked

-----------------------------------------------------------------------------------
v52                                 Discrimination of respondent's group: sexuality
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dscrsex

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,096         0  Not marked
                           229         1  Marked

-----------------------------------------------------------------------------------
v53                                    Ever been divorced/had civil union dissolved
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  dvrcdeva

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  259/39,325

            tabulation:  Freq.   Numeric  Label
                         6,429         1  Yes
                        32,637         2  No
                           182        .a  Refusal
                            58        .b  Don't know
                            19        .c  No answer

-----------------------------------------------------------------------------------
v54                                                    Doing last 7 days: education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edctn

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        35,380         0  Not marked
                         3,945         1  Marked

-----------------------------------------------------------------------------------
v55                                            Partner doing last 7 days: education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edctnp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,853         0  Not marked
                           472         1  Marked

-----------------------------------------------------------------------------------
v56                                                      Highest level of education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edulvla

                 range:  [1,55]                       units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  137/39,325

            tabulation:  Freq.   Numeric  Label
                         3,998         1  Less than lower secondary
                                          education (ISCED 0-1)
                         6,626         2  Lower secondary education
                                          completed (ISCED 2)
                        14,002         3  Upper secondary education
                                          completed (ISCED 3)
                         2,581         4  Post-secondary non-tertiary
                                          education completed (ISCED 4)
                        11,865         5  Tertiary education completed
                                          (ISCED 5-6)
                           116        55  Other
                            54        .a  Refusal
                            71        .b  Don't know
                            12        .c  No answer

-----------------------------------------------------------------------------------
v57                                                      Highest level of education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edulvlb

                 range:  [0,5555]                     units:  1
         unique values:  28                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  137/39,325

              examples:  213   General ISCED 2A, access ISCED 3A general/all 3
                         321   Vocational ISCED 3C >= 2 years, no access ISCED 5
                         323   Vocational ISCED 3A, access upper tier ISCED 5A/all 
> 5
                         610   ISCED 5A medium, bachelor/equivalent from lower tier
>  tertiary

-----------------------------------------------------------------------------------
v58                                             Father's highest level of education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edulvlfa

                 range:  [1,55]                       units:  1
         unique values:  6                        missing .:  1,662/39,325
       unique mv codes:  4                       missing .*:  4,010/39,325

            tabulation:  Freq.   Numeric  Label
                        10,879         1  Less than lower secondary
                                          education (ISCED 0-1)
                         5,820         2  Lower secondary education
                                          completed (ISCED 2)
                         9,506         3  Upper secondary education
                                          completed (ISCED 3)
                         1,286         4  Post-secondary non-tertiary
                                          education completed (ISCED 4)
                         6,026         5  Tertiary education completed
                                          (ISCED 5-6)
                           136        55  Other
                         1,662         .  
                           141        .a  Refusal
                         3,855        .b  Don't know
                            14        .c  No answer

-----------------------------------------------------------------------------------
v59                                             Father's highest level of education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edulvlfb

                 range:  [0,5555]                     units:  1
         unique values:  28                       missing .:  1,662/39,325
       unique mv codes:  4                       missing .*:  4,010/39,325

              examples:  113   ISCED 1, completed primary education
                         223   Vocational ISCED 2, access ISCED 3 general/all
                         322   Vocational ISCED 3A, access ISCED 5B/ lower tier 5A
                         720   ISCED 5A long, master/equivalent from upper/single t
> ier tertiary

-----------------------------------------------------------------------------------
v60                                             Mother's highest level of education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edulvlma

                 range:  [1,55]                       units:  1
         unique values:  6                        missing .:  1,662/39,325
       unique mv codes:  4                       missing .*:  2,555/39,325

            tabulation:  Freq.   Numeric  Label
                        12,401         1  Less than lower secondary
                                          education (ISCED 0-1)
                         7,179         2  Lower secondary education
                                          completed (ISCED 2)
                         9,155         3  Upper secondary education
                                          completed (ISCED 3)
                         1,348         4  Post-secondary non-tertiary
                                          education completed (ISCED 4)
                         4,934         5  Tertiary education completed
                                          (ISCED 5-6)
                            91        55  Other
                         1,662         .  
                           130        .a  Refusal
                         2,406        .b  Don't know
                            19        .c  No answer

-----------------------------------------------------------------------------------
v61                                             Mother's highest level of education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edulvlmb

                 range:  [0,5555]                     units:  1
         unique values:  28                       missing .:  1,662/39,325
       unique mv codes:  4                       missing .*:  2,555/39,325

              examples:  113   ISCED 1, completed primary education
                         213   General ISCED 2A, access ISCED 3A general/all 3
                         321   Vocational ISCED 3C >= 2 years, no access ISCED 5
                         520   ISCED 5B short, advanced vocational qualifications

-----------------------------------------------------------------------------------
v62                                            Partner's highest level of education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edulvlpa

                 range:  [1,55]                       units:  1
         unique values:  6                        missing .:  1,662/39,325
       unique mv codes:  5                       missing .*:  15,846/39,325

            tabulation:  Freq.   Numeric  Label
                         1,954         1  Less than lower secondary
                                          education (ISCED 0-1)
                         3,015         2  Lower secondary education
                                          completed (ISCED 2)
                         7,965         3  Upper secondary education
                                          completed (ISCED 3)
                         1,507         4  Post-secondary non-tertiary
                                          education completed (ISCED 4)
                         7,313         5  Tertiary education completed
                                          (ISCED 5-6)
                            63        55  Other
                         1,662         .  
                        15,315        .a  Not applicable
                            76        .b  Refusal
                           274        .c  Don't know
                           181        .d  No answer

-----------------------------------------------------------------------------------
v63                                            Partner's highest level of education
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  edulvlpb

                 range:  [0,5555]                     units:  1
         unique values:  28                       missing .:  1,662/39,325
       unique mv codes:  5                       missing .*:  15,846/39,325

              examples:  321   Vocational ISCED 3C >= 2 years, no access ISCED 5
                         520   ISCED 5B short, advanced vocational qualifications
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v64                                          Years of full-time education completed
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  eduyrs, but 44 nonmissing values are not labeled

                 range:  [0,50]                       units:  1
         unique values:  44                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  349/39,325

              examples:  10    
                         12    
                         14    
                         16    

-----------------------------------------------------------------------------------
v65                                          Highest level of education, ES - ISCED
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  eisced

                 range:  [1,55]                       units:  1
         unique values:  8                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  137/39,325

            tabulation:  Freq.   Numeric  Label
                         3,998         1  ES-ISCED I , less than lower
                                          secondary
                         6,626         2  ES-ISCED II, lower secondary
                         7,053         3  ES-ISCED IIIb, lower tier upper
                                          secondary
                         6,949         4  ES-ISCED IIIa, upper tier upper
                                          secondary
                         5,558         5  ES-ISCED IV, advanced
                                          vocational, sub-degree
                         4,254         6  ES-ISCED V1, lower tertiary
                                          education, BA level
                         4,634         7  ES-ISCED V2, higher tertiary
                                          education, >= MA level
                           116        55  Other
                            54        .a  Refusal
                            71        .b  Don't know
                            12        .c  No answer

-----------------------------------------------------------------------------------
v66                                 Father's highest level of education, ES - ISCED
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  eiscedf

                 range:  [1,55]                       units:  1
         unique values:  8                        missing .:  1,662/39,325
       unique mv codes:  4                       missing .*:  4,010/39,325

            tabulation:  Freq.   Numeric  Label
                        10,879         1  ES-ISCED I , less than lower
                                          secondary
                         5,820         2  ES-ISCED II, lower secondary
                         6,174         3  ES-ISCED IIIb, lower tier upper
                                          secondary
                         3,332         4  ES-ISCED IIIa, upper tier upper
                                          secondary
                         2,979         5  ES-ISCED IV, advanced
                                          vocational, sub-degree
                         1,696         6  ES-ISCED V1, lower tertiary
                                          education, BA level
                         2,637         7  ES-ISCED V2, higher tertiary
                                          education, >= MA level
                           136        55  Other
                         1,662         .  
                           141        .a  Refusal
                         3,855        .b  Don't know
                            14        .c  No answer

-----------------------------------------------------------------------------------
v67                                 Mother's highest level of education, ES - ISCED
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  eiscedm

                 range:  [1,55]                       units:  1
         unique values:  8                        missing .:  1,662/39,325
       unique mv codes:  4                       missing .*:  2,555/39,325

            tabulation:  Freq.   Numeric  Label
                        12,401         1  ES-ISCED I , less than lower
                                          secondary
                         7,179         2  ES-ISCED II, lower secondary
                         5,268         3  ES-ISCED IIIb, lower tier upper
                                          secondary
                         3,887         4  ES-ISCED IIIa, upper tier upper
                                          secondary
                         2,804         5  ES-ISCED IV, advanced
                                          vocational, sub-degree
                         1,770         6  ES-ISCED V1, lower tertiary
                                          education, BA level
                         1,708         7  ES-ISCED V2, higher tertiary
                                          education, >= MA level
                            91        55  Other
                         1,662         .  
                           130        .a  Refusal
                         2,406        .b  Don't know
                            19        .c  No answer

-----------------------------------------------------------------------------------
v68                                Partner's highest level of education, ES - ISCED
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  eiscedp

                 range:  [1,55]                       units:  1
         unique values:  8                        missing .:  1,662/39,325
       unique mv codes:  5                       missing .*:  15,846/39,325

            tabulation:  Freq.   Numeric  Label
                         1,954         1  ES-ISCED I , less than lower
                                          secondary
                         3,015         2  ES-ISCED II, lower secondary
                         4,325         3  ES-ISCED IIIb, lower tier upper
                                          secondary
                         3,640         4  ES-ISCED IIIa, upper tier upper
                                          secondary
                         3,278         5  ES-ISCED IV, advanced
                                          vocational, sub-degree
                         2,543         6  ES-ISCED V1, lower tertiary
                                          education, BA level
                         2,999         7  ES-ISCED V2, higher tertiary
                                          education, >= MA level
                            63        55  Other
                         1,662         .  
                        15,315        .a  Not applicable
                            76        .b  Refusal
                           274        .c  Don't know
                           181        .d  No answer

-----------------------------------------------------------------------------------
v69                                          Number of employees respondent has/had
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  emplno, but 58 nonmissing values are not labeled

                 range:  [0,6000]                     units:  1
         unique values:  58                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  35,274/39,325

              examples:  .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v70                                                             Employment relation
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  emplrel

                 range:  [1,3]                        units:  1
         unique values:  3                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  3,275/39,325

            tabulation:  Freq.   Numeric  Label
                        31,280         1  Employee
                         4,159         2  Self-employed
                           611         3  Working for own family business
                         3,113        .a  Not applicable
                            27        .b  Refusal
                            99        .c  Don't know
                            36        .d  No answer

-----------------------------------------------------------------------------------
v71                                                   Partner's employment relation
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  emprelp

                 range:  [1,3]                        units:  1
         unique values:  3                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  25,081/39,325

            tabulation:  Freq.   Numeric  Label
                        12,010         1  Employee
                         1,994         2  Self-employed
                           240         3  Working for own family business
                        24,754        .a  Not applicable
                            25        .b  Refusal
                            79        .c  Don't know
                           223        .d  No answer

-----------------------------------------------------------------------------------
v72                                   Father's employment status when respondent 14
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  emprf14

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,089/39,325

            tabulation:  Freq.   Numeric  Label
                        26,093         1  Employee
                         7,806         2  Self-employed
                         1,492         3  Not working
                         2,845         4  Father dead/absent
                           171        .a  Refusal
                           901        .b  Don't know
                            17        .c  No answer

-----------------------------------------------------------------------------------
v73                                   Mother's employment status when respondent 14
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  emprm14

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  586/39,325

            tabulation:  Freq.   Numeric  Label
                        19,366         1  Employee
                         3,587         2  Self-employed
                        14,935         3  Not working
                           851         4  Mother dead/absent
                           104        .a  Refusal
                           466        .b  Don't know
                            16        .c  No answer

-----------------------------------------------------------------------------------
v74                                               Enjoyed life, how often past week
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  enjlf

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  328/39,325

            tabulation:  Freq.   Numeric  Label
                         2,157         1  None or almost none of the time
                         8,855         2  Some of the time
                        17,144         3  Most of the time
                        10,841         4  All or almost all of the time
                            49        .a  Refusal
                           260        .b  Don't know
                            19        .c  No answer

-----------------------------------------------------------------------------------
v75                                                              Establishment size
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  estsz

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  4,122/39,325

            tabulation:  Freq.   Numeric  Label
                        11,296         1  Under 10
                         6,704         2  10 to 24
                         7,968         3  25 to 99
                         5,344         4  100 to 499
                         3,891         5  500 or more
                         3,113        .a  Not applicable
                            62        .b  Refusal
                           905        .c  Don't know
                            42        .d  No answer

-----------------------------------------------------------------------------------
v76                 European Union: European unification go further or gone too far
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  euftf, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  3,450/39,325

              examples:  3     
                         5     
                         6     
                         8     

-----------------------------------------------------------------------------------
v77                                                          Father born in country
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  facntr

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  241/39,325

            tabulation:  Freq.   Numeric  Label
                        32,280         1  Yes
                         6,804         2  No
                             8        .a  Refusal
                           229        .b  Don't know
                             4        .c  No answer

-----------------------------------------------------------------------------------
v78                                                        Country of birth, father
-----------------------------------------------------------------------------------

                  type:  string (str2)

         unique values:  171                      missing "":  0/39,325

              examples:  "66"
                         "66"
                         "66"
                         "66"

-----------------------------------------------------------------------------------
v79                                             Felt depressed, how often past week
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  fltdpr

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  205/39,325

            tabulation:  Freq.   Numeric  Label
                        25,120         1  None or almost none of the time
                        11,449         2  Some of the time
                         1,868         3  Most of the time
                           683         4  All or almost all of the time
                            54        .a  Refusal
                           137        .b  Don't know
                            14        .c  No answer

-----------------------------------------------------------------------------------
v80                              Felt everything did as effort, how often past week
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  flteeff

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  216/39,325

            tabulation:  Freq.   Numeric  Label
                        19,914         1  None or almost none of the time
                        14,444         2  Some of the time
                         3,422         3  Most of the time
                         1,329         4  All or almost all of the time
                            47        .a  Refusal
                           150        .b  Don't know
                            19        .c  No answer

-----------------------------------------------------------------------------------
v81                                                Felt lonely, how often past week
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  fltlnl

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  241/39,325

            tabulation:  Freq.   Numeric  Label
                        27,461         1  None or almost none of the time
                         8,842         2  Some of the time
                         1,855         3  Most of the time
                           926         4  All or almost all of the time
                            47        .a  Refusal
                           176        .b  Don't know
                            18        .c  No answer

-----------------------------------------------------------------------------------
v82                                                   Felt sad, how often past week
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  fltsd

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  243/39,325

            tabulation:  Freq.   Numeric  Label
                        21,458         1  None or almost none of the time
                        15,079         2  Some of the time
                         1,801         3  Most of the time
                           744         4  All or almost all of the time
                            51        .a  Refusal
                           179        .b  Don't know
                            13        .c  No answer

-----------------------------------------------------------------------------------
v83                                Gays and lesbians free to live life as they wish
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  freehms

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,153/39,325

            tabulation:  Freq.   Numeric  Label
                        15,452         1  Agree strongly
                        12,454         2  Agree
                         4,944         3  Neither agree nor disagree
                         2,846         4  Disagree
                         2,476         5  Disagree strongly
                            84        .a  Refusal
                         1,060        .b  Don't know
                             9        .c  No answer

-----------------------------------------------------------------------------------
v84                           Government should reduce differences in income levels
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gincdif

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  693/39,325

            tabulation:  Freq.   Numeric  Label
                        12,492         1  Agree strongly
                        15,462         2  Agree
                         5,625         3  Neither agree nor disagree
                         4,019         4  Disagree
                         1,034         5  Disagree strongly
                            31        .a  Refusal
                           654        .b  Don't know
                             8        .c  No answer

-----------------------------------------------------------------------------------
v85                                                                          Gender
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  1                       missing .*:  21/39,325

            tabulation:  Freq.   Numeric  Label
                        18,457         1  Male
                        20,847         2  Female
                            21        .a  No answer

-----------------------------------------------------------------------------------
v86                                             Gender of tenth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr10

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  14,320/39,325
       unique mv codes:  4                       missing .*:  24,960/39,325

            tabulation:  Freq.   Numeric  Label
                            21         1  Male
                            24         2  Female
                        14,320         .  
                        24,868        .a  Not applicable
                             2        .b  Refusal
                            90        .c  No answer

-----------------------------------------------------------------------------------
v87                                          Gender of eleventh person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr11

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  18,264/39,325
       unique mv codes:  3                       missing .*:  21,035/39,325

            tabulation:  Freq.   Numeric  Label
                             8         1  Male
                            18         2  Female
                        18,264         .  
                        20,944        .a  Not applicable
                            91        .c  No answer

-----------------------------------------------------------------------------------
v88                                           Gender of twelfth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr12

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  21,843/39,325
       unique mv codes:  3                       missing .*:  17,473/39,325

            tabulation:  Freq.   Numeric  Label
                             1         1  Male
                             8         2  Female
                        21,843         .  
                        17,382        .a  Not applicable
                            91        .c  No answer

-----------------------------------------------------------------------------------
v89                                        Gender of thirteenth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr13

                 range:  [1,1]                        units:  1
         unique values:  1                        missing .:  35,393/39,325
       unique mv codes:  3                       missing .*:  3,931/39,325

            tabulation:  Freq.   Numeric  Label
                             1         1  Male
                        35,393         .  
                         3,930        .a  Not applicable
                             1        .c  No answer

-----------------------------------------------------------------------------------
v90                                            Gender of second person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr2

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  8,360/39,325

            tabulation:  Freq.   Numeric  Label
                        16,061         1  Male
                        14,904         2  Female
                         8,242        .a  Not applicable
                            74        .b  Refusal
                            44        .c  No answer

-----------------------------------------------------------------------------------
v91                                             Gender of third person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr3

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  22,063/39,325

            tabulation:  Freq.   Numeric  Label
                         8,105         1  Male
                         9,157         2  Female
                        21,905        .a  Not applicable
                            97        .b  Refusal
                            61        .c  No answer

-----------------------------------------------------------------------------------
v92                                            Gender of fourth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr4

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  29,139/39,325

            tabulation:  Freq.   Numeric  Label
                         5,181         1  Male
                         5,005         2  Female
                        28,981        .a  Not applicable
                            82        .b  Refusal
                            76        .c  No answer

-----------------------------------------------------------------------------------
v93                                             Gender of fifth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr5

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  35,602/39,325

            tabulation:  Freq.   Numeric  Label
                         1,954         1  Male
                         1,769         2  Female
                        35,495        .a  Not applicable
                            37        .b  Refusal
                            70        .c  No answer

-----------------------------------------------------------------------------------
v94                                             Gender of sixth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr6

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  38,005/39,325

            tabulation:  Freq.   Numeric  Label
                           667         1  Male
                           653         2  Female
                        37,896        .a  Not applicable
                            17        .b  Refusal
                            92        .c  No answer

-----------------------------------------------------------------------------------
v95                                           Gender of seventh person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr7

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  2,097/39,325
       unique mv codes:  4                       missing .*:  36,770/39,325

            tabulation:  Freq.   Numeric  Label
                           260         1  Male
                           198         2  Female
                         2,097         .  
                        36,666        .a  Not applicable
                            10        .b  Refusal
                            94        .c  No answer

-----------------------------------------------------------------------------------
v96                                            Gender of eighth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr8

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  6,972/39,325
       unique mv codes:  4                       missing .*:  32,185/39,325

            tabulation:  Freq.   Numeric  Label
                            80         1  Male
                            88         2  Female
                         6,972         .  
                        32,084        .a  Not applicable
                             5        .b  Refusal
                            96        .c  No answer

-----------------------------------------------------------------------------------
v97                                             Gender of ninth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  gndr9

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  12,820/39,325
       unique mv codes:  4                       missing .*:  26,436/39,325

            tabulation:  Freq.   Numeric  Label
                            34         1  Male
                            35         2  Female
                        12,820         .  
                        26,344        .a  Not applicable
                             4        .b  Refusal
                            88        .c  No answer

-----------------------------------------------------------------------------------
v98                                                               How happy are you
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  happy, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  168/39,325

              examples:  6     
                         7     
                         8     
                         9     

-----------------------------------------------------------------------------------
v99                                                       Subjective general health
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  health

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  47/39,325

            tabulation:  Freq.   Numeric  Label
                         9,515         1  Very good
                        16,679         2  Good
                        10,034         3  Fair
                         2,492         4  Bad
                           558         5  Very bad
                             7        .a  Refusal
                            38        .b  Don't know
                             2        .c  No answer

-----------------------------------------------------------------------------------
v100                       Number of people living regularly as member of household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  hhmmb, but 14 nonmissing values are not labeled

                 range:  [1,14]                       units:  1
         unique values:  14                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  101/39,325

              examples:  1     
                         2     
                         3     
                         4     

-----------------------------------------------------------------------------------
v101                                      Feeling about household's income nowadays
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  hincfel

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  369/39,325

            tabulation:  Freq.   Numeric  Label
                        12,505         1  Living comfortably on present
                                          income
                        17,978         2  Coping on present income
                         6,371         3  Difficult on present income
                         2,102         4  Very difficult on present income
                            95        .a  Refusal
                           256        .b  Don't know
                            18        .c  No answer

-----------------------------------------------------------------------------------
v102                                                Main source of household income
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  hincsrc

                 range:  [1,7]                        units:  1
         unique values:  7                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  793/39,325

            tabulation:  Freq.   Numeric  Label
                        22,639         1  Wages or salaries
                         2,458         2  Income from self-employment or
                                          farming
                        10,319         3  Pensions
                           921         4  Unemployment/redundancy benefit
                         1,460         5  Any other social benefits or
                                          grants
                           253         6  Income from investments, savings
                                          etc.
                           482         7  Income from other sources
                           275        .a  Refusal
                           458        .b  Don't know
                            60        .c  No answer

-----------------------------------------------------------------------------------
v103                                                Main source of household income
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  hincsrca

                 range:  [1,8]                        units:  1
         unique values:  8                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  793/39,325

            tabulation:  Freq.   Numeric  Label
                        22,639         1  Wages or salaries
                         2,010         2  Income from self-employment
                                          (excluding farming)
                           448         3  Income from farming
                        10,319         4  Pensions
                           921         5  Unemployment/redundancy benefit
                         1,460         6  Any other social benefits or
                                          grants
                           253         7  Income from investments, savings
                                          etc.
                           482         8  Income from other sources
                           275        .a  Refusal
                           458        .b  Don't know
                            60        .c  No answer

-----------------------------------------------------------------------------------
v104                                      Household's total net income, all sources
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  hinctnta

                 range:  [1,10]                       units:  1
         unique values:  10                       missing .:  2,002/39,325
       unique mv codes:  4                       missing .*:  6,100/39,325

              examples:  3     C - 3rd decile
                         5     F - 5th decile
                         8     P - 8th decile
                         .     

-----------------------------------------------------------------------------------
v105    Hampered in daily activities by illness/disability/infirmity/mental problem
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  hlthhmp

                 range:  [1,3]                        units:  1
         unique values:  3                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  87/39,325

            tabulation:  Freq.   Numeric  Label
                         2,598         1  Yes a lot
                         7,988         2  Yes to some extent
                        28,652         3  No
                            14        .a  Refusal
                            63        .b  Don't know
                            10        .c  No answer

-----------------------------------------------------------------------------------
v106                   Doing last 7 days: housework, looking after children, others
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  hswrk

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        33,686         0  Not marked
                         5,639         1  Marked

-----------------------------------------------------------------------------------
v107           Partner doing last 7 days: housework, looking after children, others
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  hswrkp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        35,972         0  Not marked
                         3,353         1  Marked

-----------------------------------------------------------------------------------
v108                               Have a set 'basic' or contracted number of hours
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  icwhct

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  2                       missing .*:  3,204/39,325

            tabulation:  Freq.   Numeric  Label
                        34,399         1  Yes
                         1,722         2  No
                         3,117        .a  Not applicable
                            87        .b  No answer

-----------------------------------------------------------------------------------
v109                                  Immigration bad or good for country's economy
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  imbgeco, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,363/39,325

              examples:  3     
                         5     
                         6     
                         7     

-----------------------------------------------------------------------------------
v110         Allow many/few immigrants of different race/ethnic group from majority
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  imdfetn

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,041/39,325

            tabulation:  Freq.   Numeric  Label
                         5,346         1  Allow many to come and live here
                        15,857         2  Allow some
                        12,058         3  Allow a few
                         5,023         4  Allow none
                           107        .a  Refusal
                           921        .b  Don't know
                            13        .c  No answer

-----------------------------------------------------------------------------------
v111                 Allow many/few immigrants from poorer countries outside Europe
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  impcntr

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,197/39,325

            tabulation:  Freq.   Numeric  Label
                         4,383         1  Allow many to come and live here
                        13,151         2  Allow some
                        12,989         3  Allow a few
                         7,605         4  Allow none
                           114        .a  Refusal
                         1,072        .b  Don't know
                            11        .c  No answer

-----------------------------------------------------------------------------------
v112                              Important to try new and different things in life
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  impdiff

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,037/39,325

            tabulation:  Freq.   Numeric  Label
                         5,486         1  Very much like me
                        10,203         2  Like me
                         9,347         3  Somewhat like me
                         6,710         4  A little like me
                         5,223         5  Not like me
                         1,301         6  Not like me at all
                            18         .  
                           343        .a  Refusal
                           568        .b  Don't know
                           126        .c  No answer

-----------------------------------------------------------------------------------
v113                                   Important to care for nature and environment
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  impenv

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,020/39,325

            tabulation:  Freq.   Numeric  Label
                        12,495         1  Very much like me
                        15,111         2  Like me
                         6,989         3  Somewhat like me
                         2,677         4  A little like me
                           823         5  Not like me
                           192         6  Not like me at all
                            18         .  
                           338        .a  Refusal
                           557        .b  Don't know
                           125        .c  No answer

-----------------------------------------------------------------------------------
v114                                    Important to make own decisions and be free
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  impfree

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,026/39,325

            tabulation:  Freq.   Numeric  Label
                        12,109         1  Very much like me
                        14,517         2  Like me
                         7,105         3  Somewhat like me
                         3,034         4  A little like me
                         1,250         5  Not like me
                           266         6  Not like me at all
                            18         .  
                           333        .a  Refusal
                           565        .b  Don't know
                           128        .c  No answer

-----------------------------------------------------------------------------------
v115                            Important to seek fun and things that give pleasure
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  impfun

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,070/39,325

            tabulation:  Freq.   Numeric  Label
                         5,131         1  Very much like me
                        10,563         2  Like me
                         9,698         3  Somewhat like me
                         6,678         4  A little like me
                         4,518         5  Not like me
                         1,649         6  Not like me at all
                            18         .  
                           352        .a  Refusal
                           567        .b  Don't know
                           151        .c  No answer

-----------------------------------------------------------------------------------
v116                          Important to be rich, have money and expensive things
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  imprich

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  995/39,325

            tabulation:  Freq.   Numeric  Label
                         1,403         1  Very much like me
                         3,614         2  Like me
                         6,724         3  Somewhat like me
                         8,401         4  A little like me
                        12,786         5  Not like me
                         5,384         6  Not like me at all
                            18         .  
                           344        .a  Refusal
                           527        .b  Don't know
                           124        .c  No answer

-----------------------------------------------------------------------------------
v117                              Important to live in secure and safe surroundings
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  impsafe

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,022/39,325

            tabulation:  Freq.   Numeric  Label
                        11,118         1  Very much like me
                        13,416         2  Like me
                         7,171         3  Somewhat like me
                         3,759         4  A little like me
                         2,336         5  Not like me
                           485         6  Not like me at all
                            18         .  
                           338        .a  Refusal
                           563        .b  Don't know
                           121        .c  No answer

-----------------------------------------------------------------------------------
v118                                     Important to follow traditions and customs
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  imptrad

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,067/39,325

            tabulation:  Freq.   Numeric  Label
                         7,176         1  Very much like me
                        11,867         2  Like me
                         8,622         3  Somewhat like me
                         5,454         4  A little like me
                         3,699         5  Not like me
                         1,422         6  Not like me at all
                            18         .  
                           352        .a  Refusal
                           564        .b  Don't know
                           151        .c  No answer

-----------------------------------------------------------------------------------
v119                Allow many/few immigrants of same race/ethnic group as majority
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  imsmetn

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  985/39,325

            tabulation:  Freq.   Numeric  Label
                         9,600         1  Allow many to come and live here
                        17,681         2  Allow some
                         8,482         3  Allow a few
                         2,577         4  Allow none
                           111        .a  Refusal
                           864        .b  Don't know
                            10        .c  No answer

-----------------------------------------------------------------------------------
v120                   Country's cultural life undermined or enriched by immigrants
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  imueclt, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,321/39,325

              examples:  4     
                         5     
                         7     
                         8     

-----------------------------------------------------------------------------------
v121                          Immigrants make country worse or better place to live
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  imwbcnt, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,486/39,325

              examples:  3     
                         5     
                         5     
                         7     

-----------------------------------------------------------------------------------
v122        How many people with whom you can discuss intimate and personal matters
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inprdsc, but 3 nonmissing values are not labeled

                 range:  [0,6]                        units:  1
         unique values:  7                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  338/39,325

            tabulation:  Freq.   Numeric  Label
                         1,985         0  None
                         6,165         1  
                         7,956         2  
                         9,026         3  
                        10,113         4  4-6
                         2,028         5  7-9
                         1,714         6  10 or more
                            29        .a  Refusal
                           297        .b  Don't know
                            12        .c  No answer

-----------------------------------------------------------------------------------
v123                                         Place of interview: East, West Germany
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  intewde

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  36,360/39,325

            tabulation:  Freq.   Numeric  Label
                           975         1  Interview takes place in East
                                          Germany, East Berlin
                         1,990         2  Interview takes place in West
                                          Germany, West Berlin
                        36,360         .  

-----------------------------------------------------------------------------------
v124                                                 End of interview, day of month
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwdde, but 31 nonmissing values are not labeled

                 range:  [1,31]                       units:  1
         unique values:  31                       missing .:  0/39,325
       unique mv codes:  1                       missing .*:  10/39,325

              examples:  7     
                         13    
                         19    
                         25    

-----------------------------------------------------------------------------------
v125                                               Start of interview, day of month
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwdds, but 31 nonmissing values are not labeled

                 range:  [1,31]                       units:  1
         unique values:  31                       missing .:  0/39,325
       unique mv codes:  1                       missing .*:  3/39,325

              examples:  7     
                         13    
                         19    
                         25    

-----------------------------------------------------------------------------------
v126                                                         End of interview, hour
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwehh, but 24 nonmissing values are not labeled

                 range:  [0,23]                       units:  1
         unique values:  24                       missing .:  1,247/39,325
       unique mv codes:  2                       missing .*:  83/39,325

              examples:  12    
                         14    
                         16    
                         18    

-----------------------------------------------------------------------------------
v127                                                       End of interview, minute
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwemm, but 60 nonmissing values are not labeled

                 range:  [0,59]                       units:  1
         unique values:  60                       missing .:  1,247/39,325
       unique mv codes:  2                       missing .*:  83/39,325

              examples:  11    
                         24    
                         37    
                         50    

-----------------------------------------------------------------------------------
v128                                                        End of interview, month
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwmme, but 12 nonmissing values are not labeled

                 range:  [1,12]                       units:  1
         unique values:  12                       missing .:  0/39,325
       unique mv codes:  1                       missing .*:  7/39,325

              examples:  4     
                         9     
                         10    
                         11    

-----------------------------------------------------------------------------------
v129                                                      Start of interview, month
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwmms, but 12 nonmissing values are not labeled

                 range:  [1,12]                       units:  1
         unique values:  12                       missing .:  0/39,325

              examples:  4     
                         9     
                         10    
                         11    

-----------------------------------------------------------------------------------
v130                                                       Start of interview, hour
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwshh, but 24 nonmissing values are not labeled

                 range:  [0,23]                       units:  1
         unique values:  24                       missing .:  1,247/39,325
       unique mv codes:  2                       missing .*:  89/39,325

              examples:  11    
                         13    
                         16    
                         17    

-----------------------------------------------------------------------------------
v131                                                     Start of interview, minute
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwsmm, but 60 nonmissing values are not labeled

                 range:  [0,59]                       units:  1
         unique values:  60                       missing .:  1,247/39,325
       unique mv codes:  2                       missing .*:  89/39,325

              examples:  6     
                         16    
                         31    
                         47    

-----------------------------------------------------------------------------------
v132                                Interview length in minutes, main questionnaire
-----------------------------------------------------------------------------------

                  type:  numeric (double)

                 range:  [0,772]                      units:  1
         unique values:  214                      missing .:  1,574/39,325

                  mean:   57.3612
              std. dev:   21.2172

           percentiles:        10%       25%       50%       75%       90%
                                37        45        54        66        80

-----------------------------------------------------------------------------------
v133                                                         End of interview, year
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwyye, but 2 nonmissing values are not labeled

                 range:  [2014,2015]                  units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  1                       missing .*:  7/39,325

            tabulation:  Freq.   Numeric  Label
                        22,782      2014  
                        16,536      2015  
                             7        .a  Not available

-----------------------------------------------------------------------------------
v134                                                       Start of interview, year
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  inwyys, but 2 nonmissing values are not labeled

                 range:  [2014,2015]                  units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        22,797      2014  
                        16,528      2015  

-----------------------------------------------------------------------------------
v135         Allowed to influence policy decisions about activities of organisation
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  iorgact, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  3,701/39,325

              examples:  0     I have/had no influence
                         3     
                         6     
                         10    I have/had complete control

-----------------------------------------------------------------------------------
v136                         Important to seek adventures and have an exciting life
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipadvnt

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,059/39,325

            tabulation:  Freq.   Numeric  Label
                         2,501         1  Very much like me
                         5,144         2  Like me
                         7,275         3  Somewhat like me
                         7,677         4  A little like me
                        10,568         5  Not like me
                         5,083         6  Not like me at all
                            18         .  
                           351        .a  Refusal
                           568        .b  Don't know
                           140        .c  No answer

-----------------------------------------------------------------------------------
v137                                                   Important to behave properly
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipbhprp

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,099/39,325

            tabulation:  Freq.   Numeric  Label
                         6,848         1  Very much like me
                        13,786         2  Like me
                         8,806         3  Somewhat like me
                         5,037         4  A little like me
                         3,070         5  Not like me
                           661         6  Not like me at all
                            18         .  
                           347        .a  Refusal
                           606        .b  Don't know
                           146        .c  No answer

-----------------------------------------------------------------------------------
v138                                Important to think new ideas and being creative
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipcrtiv

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,049/39,325

            tabulation:  Freq.   Numeric  Label
                         8,550         1  Very much like me
                        12,320         2  Like me
                         9,312         3  Somewhat like me
                         4,521         4  A little like me
                         2,770         5  Not like me
                           785         6  Not like me at all
                            18         .  
                           331        .a  Refusal
                           601        .b  Don't know
                           117        .c  No answer

-----------------------------------------------------------------------------------
v139         Important that people are treated equally and have equal opportunities
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipeqopt

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,028/39,325

            tabulation:  Freq.   Numeric  Label
                        13,508         1  Very much like me
                        15,089         2  Like me
                         6,190         3  Somewhat like me
                         2,337         4  A little like me
                           898         5  Not like me
                           257         6  Not like me at all
                            18         .  
                           335        .a  Refusal
                           578        .b  Don't know
                           115        .c  No answer

-----------------------------------------------------------------------------------
v140                                  Important to do what is told and follow rules
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipfrule

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,190/39,325

            tabulation:  Freq.   Numeric  Label
                         4,150         1  Very much like me
                        10,276         2  Like me
                         8,966         3  Somewhat like me
                         6,708         4  A little like me
                         6,086         5  Not like me
                         1,931         6  Not like me at all
                            18         .  
                           358        .a  Refusal
                           713        .b  Don't know
                           119        .c  No answer

-----------------------------------------------------------------------------------
v141                                                  Important to have a good time
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipgdtim

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,050/39,325

            tabulation:  Freq.   Numeric  Label
                         5,956         1  Very much like me
                        11,708         2  Like me
                         9,261         3  Somewhat like me
                         5,981         4  A little like me
                         4,215         5  Not like me
                         1,136         6  Not like me at all
                            18         .  
                           339        .a  Refusal
                           580        .b  Don't know
                           131        .c  No answer

-----------------------------------------------------------------------------------
v142                        Important to help people and care for others well-being
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  iphlppl

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,002/39,325

            tabulation:  Freq.   Numeric  Label
                        10,538         1  Very much like me
                        16,103         2  Like me
                         7,858         3  Somewhat like me
                         2,867         4  A little like me
                           777         5  Not like me
                           162         6  Not like me at all
                            18         .  
                           332        .a  Refusal
                           549        .b  Don't know
                           121        .c  No answer

-----------------------------------------------------------------------------------
v143                    Important to be loyal to friends and devote to people close
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  iplylfr

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,018/39,325

            tabulation:  Freq.   Numeric  Label
                        14,746         1  Very much like me
                        16,347         2  Like me
                         4,836         3  Somewhat like me
                         1,714         4  A little like me
                           512         5  Not like me
                           134         6  Not like me at all
                            18         .  
                           337        .a  Refusal
                           547        .b  Don't know
                           134        .c  No answer

-----------------------------------------------------------------------------------
v144                          Important to be humble and modest, not draw attention
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipmodst

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,073/39,325

            tabulation:  Freq.   Numeric  Label
                         6,832         1  Very much like me
                        13,189         2  Like me
                         9,186         3  Somewhat like me
                         5,267         4  A little like me
                         3,055         5  Not like me
                           705         6  Not like me at all
                            18         .  
                           345        .a  Refusal
                           599        .b  Don't know
                           129        .c  No answer

-----------------------------------------------------------------------------------
v145                                           Important to get respect from others
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  iprspot

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,174/39,325

            tabulation:  Freq.   Numeric  Label
                         4,095         1  Very much like me
                         9,585         2  Like me
                         9,597         3  Somewhat like me
                         6,961         4  A little like me
                         6,324         5  Not like me
                         1,571         6  Not like me at all
                            18         .  
                           369        .a  Refusal
                           665        .b  Don't know
                           140        .c  No answer

-----------------------------------------------------------------------------------
v146                                     Important to show abilities and be admired
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipshabt

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,076/39,325

            tabulation:  Freq.   Numeric  Label
                         4,102         1  Very much like me
                         9,509         2  Like me
                         8,953         3  Somewhat like me
                         6,874         4  A little like me
                         6,815         5  Not like me
                         1,978         6  Not like me at all
                            18         .  
                           341        .a  Refusal
                           606        .b  Don't know
                           129        .c  No answer

-----------------------------------------------------------------------------------
v147                         Important that government is strong and ensures safety
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipstrgv

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,244/39,325

            tabulation:  Freq.   Numeric  Label
                        10,952         1  Very much like me
                        13,925         2  Like me
                         7,383         3  Somewhat like me
                         3,607         4  A little like me
                         1,718         5  Not like me
                           478         6  Not like me at all
                            18         .  
                           364        .a  Refusal
                           755        .b  Don't know
                           125        .c  No answer

-----------------------------------------------------------------------------------
v148              Important to be successful and that people recognize achievements
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipsuces

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,137/39,325

            tabulation:  Freq.   Numeric  Label
                         4,084         1  Very much like me
                         9,583         2  Like me
                         9,654         3  Somewhat like me
                         7,057         4  A little like me
                         6,080         5  Not like me
                         1,712         6  Not like me at all
                            18         .  
                           340        .a  Refusal
                           672        .b  Don't know
                           125        .c  No answer

-----------------------------------------------------------------------------------
v149                                       Important to understand different people
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ipudrst

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  18/39,325
       unique mv codes:  4                       missing .*:  1,073/39,325

            tabulation:  Freq.   Numeric  Label
                         8,033         1  Very much like me
                        16,090         2  Like me
                         8,790         3  Somewhat like me
                         3,633         4  A little like me
                         1,345         5  Not like me
                           343         6  Not like me at all
                            18         .  
                           335        .a  Refusal
                           605        .b  Don't know
                           133        .c  No answer

-----------------------------------------------------------------------------------
v150                                                             Occupation, ISCO08
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  isco08

                 range:  [0,9629]                     units:  1
         unique values:  549                      missing .:  0/39,325
       unique mv codes:  4                       missing .*:  3,622/39,325

              examples:  2424  Training and staff development professionals
                         4120  Secretaries (general)
                         5322  Home-based personal care workers
                         8332  Heavy truck and lorry drivers

-----------------------------------------------------------------------------------
v151                                                     Occupation partner, ISCO08
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  isco08p

                 range:  [0,9629]                     units:  1
         unique values:  524                      missing .:  0/39,325
       unique mv codes:  4                       missing .*:  25,339/39,325

              examples:  5120  Cooks
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v152                                    Responsible for supervising other employees
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  jbspv

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  3,260/39,325

            tabulation:  Freq.   Numeric  Label
                        10,783         1  Yes
                        25,282         2  No
                         3,113        .a  Not applicable
                            32        .b  Refusal
                            76        .c  Don't know
                            39        .d  No answer

-----------------------------------------------------------------------------------
v153                                    What year you first came to live in country
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  livecnta, but 88 nonmissing values are not labeled

                 range:  [1921,2015]                  units:  1
         unique values:  88                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  34,938/39,325

              examples:  .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v154                            Language most often spoken at home: first mentioned
-----------------------------------------------------------------------------------

                  type:  string (str3)

         unique values:  123                      missing "":  0/39,325

              examples:  "ENG"
                         "FRE"
                         "HEB"
                         "POL"

-----------------------------------------------------------------------------------
v155                           Language most often spoken at home: second mentioned
-----------------------------------------------------------------------------------

                  type:  string (str3)

         unique values:  129                      missing "":  0/39,325

              examples:  "000"
                         "000"
                         "000"
                         "999"

-----------------------------------------------------------------------------------
v156                                                  Placement on left right scale
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  lrscale, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  4,242/39,325

              examples:  3     
                         5     
                         6     
                         8     

-----------------------------------------------------------------------------------
v157                               Ever lived with a partner, without being married
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  lvgptnea

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  5,179/39,325

            tabulation:  Freq.   Numeric  Label
                        10,732         1  Yes
                        23,414         2  No
                         4,062        .a  Not applicable
                           191        .b  Refusal
                            57        .c  Don't know
                           869        .d  No answer

-----------------------------------------------------------------------------------
v158                                                      Main activity last 7 days
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  mainact

                 range:  [1,9]                        units:  1
         unique values:  9                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  33,971/39,325

            tabulation:  Freq.   Numeric  Label
                         2,580         1  Paid work
                           488         2  Education
                           137         3  Unemployed, looking for job
                            57         4  Unemployed, not looking for job
                           192         5  Permanently sick or disabled
                           996         6  Retired
                             6         7  Community or military service
                           851         8  Housework, looking after
                                          children, others
                            47         9  Other
                        33,883        .a  Not applicable
                            38        .c  Don't know
                            50        .d  No answer

-----------------------------------------------------------------------------------
v159                                               Legal marital status, post coded
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  maritalb

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  401/39,325

            tabulation:  Freq.   Numeric  Label
                        19,439         1  Legally married
                           337         2  In a legally registered civil
                                          union
                           217         3  Legally separated
                         3,970         4  Legally divorced/civil union
                                          dissolved
                         3,438         5  Widowed/civil partner died
                        11,523         6  None of these (NEVER married or
                                          in legally registered civil
                                          union)
                           100        .a  Refusal
                           136        .b  Don't know
                           165        .c  No answer

-----------------------------------------------------------------------------------
v160                                                           Legal marital status
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  marsts

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  19,399/39,325

            tabulation:  Freq.   Numeric  Label
                           740         1  Legally married
                           106         2  In a legally registered civil
                                          union
                           201         3  Legally separated
                         3,918         4  Legally divorced/civil union
                                          dissolved
                         3,438         5  Widowed/civil partner died
                        11,523         6  None of these (NEVER married or
                                          in legally registered civil
                                          union)
                        19,011        .a  Not applicable
                            87        .b  Refusal
                           109        .c  Don't know
                           192        .d  No answer

-----------------------------------------------------------------------------------
v161                                                       Country of birth, mother
-----------------------------------------------------------------------------------

                  type:  string (str2)

         unique values:  173                      missing "":  0/39,325

              examples:  "66"
                         "66"
                         "66"
                         "66"

-----------------------------------------------------------------------------------
v162                                  Member of trade union or similar organisation
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  mbtru

                 range:  [1,3]                        units:  1
         unique values:  3                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  337/39,325

            tabulation:  Freq.   Numeric  Label
                         7,070         1  Yes, currently
                         9,007         2  Yes, previously
                        22,911         3  No
                            52        .a  Refusal
                           274        .b  Don't know
                            11        .c  No answer

-----------------------------------------------------------------------------------
v163                        Main activity, last 7 days. All respondents. Post coded
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  mnactic

                 range:  [1,9]                        units:  1
         unique values:  9                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  140/39,325

            tabulation:  Freq.   Numeric  Label
                        19,642         1  Paid work
                         3,295         2  Education
                         1,497         3  Unemployed, looking for job
                           614         4  Unemployed, not looking for job
                         1,054         5  Permanently sick or disabled
                         9,962         6  Retired
                            58         7  Community or military service
                         2,640         8  Housework, looking after
                                          children, others
                           423         9  Other
                            28        .b  Refusal
                            58        .c  Don't know
                            54        .d  No answer

-----------------------------------------------------------------------------------
v164                                            Partner's main activity last 7 days
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  mnactp

                 range:  [1,9]                        units:  1
         unique values:  8                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  36,971/39,325

            tabulation:  Freq.   Numeric  Label
                         1,241         1  Paid work
                            75         2  Education
                            55         3  Unemployed, looking for job
                            15         4  Unemployed, not looking for job
                            68         5  Permanently sick or disabled
                           436         6  Retired
                           443         8  Housework, looking after
                                          children, others
                            21         9  Other
                        36,731        .a  Not applicable
                             3        .b  Refusal
                            12        .c  Don't know
                           225        .d  No answer

-----------------------------------------------------------------------------------
v165                                                         Mother born in country
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  mocntr

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  91/39,325

            tabulation:  Freq.   Numeric  Label
                        32,714         1  Yes
                         6,520         2  No
                            10        .a  Refusal
                            75        .b  Don't know
                             6        .c  No answer

-----------------------------------------------------------------------------------
v166                                  Administration of supplementary questionnaire
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  mode

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  1                       missing .*:  182/39,325

            tabulation:  Freq.   Numeric  Label
                        33,834         1  Face to face interview
                         5,309         2  Self completion
                           182        .b  Not available

-----------------------------------------------------------------------------------
v167                                                           Industry, NACE rev.2
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  nacer2

                 range:  [1,99]                       units:  1
         unique values:  88                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  3,835/39,325

              examples:  35    Electricity, gas, steam and air conditioning supply
                         49    Land transport and transport via pipelines
                         81    Services to buildings and landscape activities
                         86    Human health activities

-----------------------------------------------------------------------------------
v168                                        Number of people responsible for in job
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  njbspv, but 155 nonmissing values are not labeled

                 range:  [0,60000]                    units:  1
         unique values:  155                      missing .:  0/39,325
       unique mv codes:  4                       missing .*:  28,774/39,325

              examples:  12    
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v169                                         Father's occupation when respondent 14
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  occf14b

                 range:  [1,9]                        units:  1
         unique values:  9                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  5,795/39,325

            tabulation:  Freq.   Numeric  Label
                         3,524         1  Professional and technical
                                          occupations
                         1,847         2  Higher administrator occupations
                         1,839         3  Clerical occupations
                         1,994         4  Sales occupations
                         2,312         5  Service occupations
                         7,672         6  Skilled worker
                         5,997         7  Semi-skilled worker
                         3,385         8  Unskilled worker
                         4,960         9  Farm worker
                         4,432        .a  Not applicable
                           107        .b  Refusal
                         1,227        .c  Don't know
                            29        .d  No answer

-----------------------------------------------------------------------------------
v170                                         Mother's occupation when respondent 14
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  occm14b

                 range:  [1,9]                        units:  1
         unique values:  9                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  16,732/39,325

            tabulation:  Freq.   Numeric  Label
                         2,718         1  Professional and technical
                                          occupations
                           443         2  Higher administrator occupations
                         3,482         3  Clerical occupations
                         2,081         4  Sales occupations
                         3,643         5  Service occupations
                         1,699         6  Skilled worker
                         2,295         7  Semi-skilled worker
                         3,342         8  Unskilled worker
                         2,890         9  Farm worker
                        15,886        .a  Not applicable
                            50        .b  Refusal
                           777        .c  Don't know
                            19        .d  No answer

-----------------------------------------------------------------------------------
v171                              Lives with husband/wife/partner at household grid
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  partner

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  1                       missing .*:  148/39,325

            tabulation:  Freq.   Numeric  Label
                        23,156         1  Lives with husband/wife/partner
                                          at household grid
                        16,021         2  Does not
                           148        .b  Not available

-----------------------------------------------------------------------------------
v172                       Taken part in lawful public demonstration last 12 months
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  pbldmn

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  73/39,325

            tabulation:  Freq.   Numeric  Label
                         2,883         1  Yes
                        36,369         2  No
                             8        .a  Refusal
                            58        .b  Don't know
                             7        .c  No answer

-----------------------------------------------------------------------------------
v173                                                            Ever had a paid job
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  pdjobev

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  21,438/39,325

            tabulation:  Freq.   Numeric  Label
                        14,835         1  Yes
                         3,052         2  No
                        21,351        .a  Not applicable
                            47        .b  Refusal
                            22        .c  Don't know
                            18        .d  No answer

-----------------------------------------------------------------------------------
v174                                                          Year last in paid job
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  pdjobyr, but 77 nonmissing values are not labeled

                 range:  [1932,2015]                  units:  1
         unique values:  77                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  25,350/39,325

              examples:  2009  
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v175                                                   Doing last 7 days: paid work
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  pdwrk

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        18,741         0  Not marked
                        20,584         1  Marked

-----------------------------------------------------------------------------------
v176                                           Partner doing last 7 days: paid work
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  pdwrkp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        25,296         0  Not marked
                        14,029         1  Marked

-----------------------------------------------------------------------------------
v177                                                     How interested in politics
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  polintr

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  107/39,325

            tabulation:  Freq.   Numeric  Label
                         4,729         1  Very interested
                        14,421         2  Quite interested
                        12,836         3  Hardly interested
                         7,232         4  Not at all interested
                            18        .a  Refusal
                            77        .b  Don't know
                            12        .c  No answer

-----------------------------------------------------------------------------------
v178                    Most people try to take advantage of you, or try to be fair
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  pplfair, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  271/39,325

              examples:  4     
                         5     
                         7     
                         8     

-----------------------------------------------------------------------------------
v179           Most of the time people helpful or mostly looking out for themselves
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  pplhlp, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  140/39,325

              examples:  3     
                         5     
                         6     
                         7     

-----------------------------------------------------------------------------------
v180                         Most people can be trusted or you can't be too careful
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  ppltrst, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  75/39,325

              examples:  3     
                         5     
                         6     
                         7     

-----------------------------------------------------------------------------------
v181                                How often pray apart from at religious services
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  pray

                 range:  [1,7]                        units:  1
         unique values:  7                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  508/39,325

            tabulation:  Freq.   Numeric  Label
                         7,198         1  Every day
                         2,792         2  More than once a week
                         2,259         3  Once a week
                         2,247         4  At least once a month
                         1,992         5  Only on special holy days
                         6,094         6  Less often
                        16,235         7  Never
                           119        .a  Refusal
                           365        .b  Don't know
                            24        .c  No answer

-----------------------------------------------------------------------------------
v182                                                             How close to party
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  prtdgcl

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  20,844/39,325

            tabulation:  Freq.   Numeric  Label
                         2,205         1  Very close
                        11,773         2  Quite close
                         4,087         3  Not close
                           416         4  Not at all close
                        20,478        .a  Not applicable
                             5        .b  Refusal
                           207        .c  Don't know
                           154        .d  No answer

-----------------------------------------------------------------------------------
v183                   Political system allows people to have influence on politics
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  psppipl, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  883/39,325

              examples:  1     
                         3     
                         4     
                         6     

-----------------------------------------------------------------------------------
v184           Political system allows people to have a say in what government does
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  psppsgv, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  939/39,325

              examples:  1     
                         3     
                         4     
                         6     

-----------------------------------------------------------------------------------
v185                                                                  Regional unit
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  regunit

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                         5,180         1  NUTS level 1
                        16,325         2  NUTS level 2
                        15,311         3  NUTS level 3
                         2,509         4  Regional unit not part of the
                                          NUTS nomenclature

-----------------------------------------------------------------------------------
v186               How often attend religious services apart from special occasions
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rlgatnd

                 range:  [1,7]                        units:  1
         unique values:  7                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  159/39,325

            tabulation:  Freq.   Numeric  Label
                           471         1  Every day
                           924         2  More than once a week
                         4,038         3  Once a week
                         3,714         4  At least once a month
                         7,889         5  Only on special holy days
                         7,719         6  Less often
                        14,411         7  Never
                            42        .a  Refusal
                            89        .b  Don't know
                            28        .c  No answer

-----------------------------------------------------------------------------------
v187                               Belonging to particular religion or denomination
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rlgblg

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  177/39,325

            tabulation:  Freq.   Numeric  Label
                        22,582         1  Yes
                        16,566         2  No
                            48        .a  Refusal
                           119        .b  Don't know
                            10        .c  No answer

-----------------------------------------------------------------------------------
v188                          Ever belonging to particular religion or denomination
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rlgblge

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  22,722/39,325

            tabulation:  Freq.   Numeric  Label
                         4,203         1  Yes
                        12,400         2  No
                        22,581        .a  Not applicable
                            37        .b  Refusal
                            88        .c  Don't know
                            16        .d  No answer

-----------------------------------------------------------------------------------
v189                                                          How religious are you
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rlgdgr, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  283/39,325

              examples:  1     
                         3     
                         5     
                         7     

-----------------------------------------------------------------------------------
v190                               Religion or denomination belonging to at present
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rlgdnm

                 range:  [1,8]                        units:  1
         unique values:  8                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  16,835/39,325

            tabulation:  Freq.   Numeric  Label
                        12,457         1  Roman Catholic
                         5,373         2  Protestant
                           824         3  Eastern Orthodox
                           447         4  Other Christian denomination
                         2,002         5  Jewish
                         1,119         6  Islamic
                           146         7  Eastern religions
                           122         8  Other non-Christian religions
                        16,733        .a  Not applicable
                            70        .b  Refusal
                            32        .c  No answer

-----------------------------------------------------------------------------------
v191                              Religion or denomination belonging to in the past
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rlgdnme

                 range:  [1,8]                        units:  1
         unique values:  8                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  35,140/39,325

            tabulation:  Freq.   Numeric  Label
                         2,345         1  Roman Catholic
                         1,545         2  Protestant
                            49         3  Eastern Orthodox
                           103         4  Other Christian denomination
                            16         5  Jewish
                            47         6  Islamic
                            49         7  Eastern religions
                            31         8  Other non-Christian religions
                        35,106        .a  Not applicable
                             8        .b  Refusal
                            26        .c  No answer

-----------------------------------------------------------------------------------
v192                          Tenth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship10

                 range:  [2,5]                        units:  1
         unique values:  3                        missing .:  14,320/39,325
       unique mv codes:  4                       missing .*:  24,959/39,325

            tabulation:  Freq.   Numeric  Label
                            21         2  Son/daughter/step/adopted
                            23         4  Other relative
                             2         5  Other non-relative
                        14,320         .  
                        24,868        .a  Not applicable
                             1        .b  Refusal
                            90        .d  No answer

-----------------------------------------------------------------------------------
v193                       Eleventh person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship11

                 range:  [2,5]                        units:  1
         unique values:  3                        missing .:  18,264/39,325
       unique mv codes:  3                       missing .*:  21,034/39,325

            tabulation:  Freq.   Numeric  Label
                            14         2  Son/daughter/step/adopted
                            12         4  Other relative
                             1         5  Other non-relative
                        18,264         .  
                        20,944        .a  Not applicable
                            90        .d  No answer

-----------------------------------------------------------------------------------
v194                        Twelfth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship12

                 range:  [2,4]                        units:  1
         unique values:  2                        missing .:  21,843/39,325
       unique mv codes:  3                       missing .*:  17,472/39,325

            tabulation:  Freq.   Numeric  Label
                             9         2  Son/daughter/step/adopted
                             1         4  Other relative
                        21,843         .  
                        17,382        .a  Not applicable
                            90        .d  No answer

-----------------------------------------------------------------------------------
v195                     Thirteenth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship13

                 range:  [2,2]                        units:  1
         unique values:  1                        missing .:  35,393/39,325
       unique mv codes:  3                       missing .*:  3,931/39,325

            tabulation:  Freq.   Numeric  Label
                             1         2  Son/daughter/step/adopted
                        35,393         .  
                         3,930        .a  Not applicable
                             1        .d  No answer

-----------------------------------------------------------------------------------
v196                         Second person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship2

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  8,391/39,325

            tabulation:  Freq.   Numeric  Label
                        22,487         1  Husband/wife/partner
                         2,256         2  Son/daughter/step/adopted
                         4,923         3  Parent/parent-in-law
                           821         4  Other relative
                           447         5  Other non-relative
                         8,242        .a  Not applicable
                            67        .b  Refusal
                            41        .c  Don't know
                            41        .d  No answer

-----------------------------------------------------------------------------------
v197                          Third person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship3

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  22,036/39,325

            tabulation:  Freq.   Numeric  Label
                           442         1  Husband/wife/partner
                        11,920         2  Son/daughter/step/adopted
                         3,575         3  Parent/parent-in-law
                         1,034         4  Other relative
                           318         5  Other non-relative
                        21,905        .a  Not applicable
                            45        .b  Refusal
                            33        .c  Don't know
                            53        .d  No answer

-----------------------------------------------------------------------------------
v198                         Fourth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship4

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  29,110/39,325

            tabulation:  Freq.   Numeric  Label
                           199         1  Husband/wife/partner
                         6,896         2  Son/daughter/step/adopted
                           301         3  Parent/parent-in-law
                         2,651         4  Other relative
                           168         5  Other non-relative
                        28,981        .a  Not applicable
                            41        .b  Refusal
                            24        .c  Don't know
                            64        .d  No answer

-----------------------------------------------------------------------------------
v199                          Fifth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship5

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  35,601/39,325

            tabulation:  Freq.   Numeric  Label
                            34         1  Husband/wife/partner
                         2,283         2  Son/daughter/step/adopted
                            83         3  Parent/parent-in-law
                         1,257         4  Other relative
                            67         5  Other non-relative
                        35,495        .a  Not applicable
                            23        .b  Refusal
                            14        .c  Don't know
                            69        .d  No answer

-----------------------------------------------------------------------------------
v200                          Sixth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship6

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  37,998/39,325

            tabulation:  Freq.   Numeric  Label
                             9         1  Husband/wife/partner
                           706         2  Son/daughter/step/adopted
                            23         3  Parent/parent-in-law
                           562         4  Other relative
                            27         5  Other non-relative
                        37,896        .a  Not applicable
                             9        .b  Refusal
                             2        .c  Don't know
                            91        .d  No answer

-----------------------------------------------------------------------------------
v201                        Seventh person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship7

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  2,097/39,325
       unique mv codes:  4                       missing .*:  36,767/39,325

            tabulation:  Freq.   Numeric  Label
                             3         1  Husband/wife/partner
                           219         2  Son/daughter/step/adopted
                             5         3  Parent/parent-in-law
                           219         4  Other relative
                            15         5  Other non-relative
                         2,097         .  
                        36,666        .a  Not applicable
                             7        .b  Refusal
                            94        .d  No answer

-----------------------------------------------------------------------------------
v202                         Eighth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship8

                 range:  [2,5]                        units:  1
         unique values:  3                        missing .:  6,972/39,325
       unique mv codes:  4                       missing .*:  32,184/39,325

            tabulation:  Freq.   Numeric  Label
                            76         2  Son/daughter/step/adopted
                            87         4  Other relative
                             6         5  Other non-relative
                         6,972         .  
                        32,084        .a  Not applicable
                             4        .b  Refusal
                            96        .d  No answer

-----------------------------------------------------------------------------------
v203                          Ninth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rship9

                 range:  [2,5]                        units:  1
         unique values:  3                        missing .:  12,820/39,325
       unique mv codes:  4                       missing .*:  26,433/39,325

            tabulation:  Freq.   Numeric  Label
                            33         2  Son/daughter/step/adopted
                            35         4  Other relative
                             4         5  Other non-relative
                        12,820         .  
                        26,344        .a  Not applicable
                             1        .b  Refusal
                            88        .d  No answer

-----------------------------------------------------------------------------------
v204                          Tenth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa10

                 range:  [2,6]                        units:  1
         unique values:  4                        missing .:  14,320/39,325
       unique mv codes:  4                       missing .*:  24,959/39,325

            tabulation:  Freq.   Numeric  Label
                            21         2  Son/daughter/step/adopted/foster
                            18         4  Brother/sister/step/adopted/fost
                                          er
                             5         5  Other relative
                             2         6  Other non-relative
                        14,320         .  
                        24,868        .a  Not applicable
                             1        .b  Refusal
                            90        .d  No answer

-----------------------------------------------------------------------------------
v205                       Eleventh person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa11

                 range:  [2,6]                        units:  1
         unique values:  4                        missing .:  18,264/39,325
       unique mv codes:  3                       missing .*:  21,034/39,325

            tabulation:  Freq.   Numeric  Label
                            14         2  Son/daughter/step/adopted/foster
                             6         4  Brother/sister/step/adopted/fost
                                          er
                             6         5  Other relative
                             1         6  Other non-relative
                        18,264         .  
                        20,944        .a  Not applicable
                            90        .d  No answer

-----------------------------------------------------------------------------------
v206                        Twelfth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa12

                 range:  [2,4]                        units:  1
         unique values:  2                        missing .:  21,843/39,325
       unique mv codes:  3                       missing .*:  17,472/39,325

            tabulation:  Freq.   Numeric  Label
                             9         2  Son/daughter/step/adopted/foster
                             1         4  Brother/sister/step/adopted/fost
                                          er
                        21,843         .  
                        17,382        .a  Not applicable
                            90        .d  No answer

-----------------------------------------------------------------------------------
v207                     Thirteenth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa13

                 range:  [2,2]                        units:  1
         unique values:  1                        missing .:  35,393/39,325
       unique mv codes:  3                       missing .*:  3,931/39,325

            tabulation:  Freq.   Numeric  Label
                             1         2  Son/daughter/step/adopted/foster
                        35,393         .  
                         3,930        .a  Not applicable
                             1        .d  No answer

-----------------------------------------------------------------------------------
v208                         Second person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa2

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  8,391/39,325

            tabulation:  Freq.   Numeric  Label
                        22,487         1  Husband/wife/partner
                         2,256         2  Son/daughter/step/adopted/foster
                         4,923         3  Parent/parent-in-law
                           327         4  Brother/sister/step/adopted/fost
                                          er
                           494         5  Other relative
                           447         6  Other non-relative
                         8,242        .a  Not applicable
                            67        .b  Refusal
                            41        .c  Don't know
                            41        .d  No answer

-----------------------------------------------------------------------------------
v209                          Third person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa3

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  22,036/39,325

            tabulation:  Freq.   Numeric  Label
                           442         1  Husband/wife/partner
                        11,920         2  Son/daughter/step/adopted/foster
                         3,575         3  Parent/parent-in-law
                           622         4  Brother/sister/step/adopted/fost
                                          er
                           412         5  Other relative
                           318         6  Other non-relative
                        21,905        .a  Not applicable
                            45        .b  Refusal
                            33        .c  Don't know
                            53        .d  No answer

-----------------------------------------------------------------------------------
v210                         Fourth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa4

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  29,110/39,325

            tabulation:  Freq.   Numeric  Label
                           199         1  Husband/wife/partner
                         6,896         2  Son/daughter/step/adopted/foster
                           301         3  Parent/parent-in-law
                         2,265         4  Brother/sister/step/adopted/fost
                                          er
                           386         5  Other relative
                           168         6  Other non-relative
                        28,981        .a  Not applicable
                            41        .b  Refusal
                            24        .c  Don't know
                            64        .d  No answer

-----------------------------------------------------------------------------------
v211                          Fifth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa5

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  35,601/39,325

            tabulation:  Freq.   Numeric  Label
                            34         1  Husband/wife/partner
                         2,283         2  Son/daughter/step/adopted/foster
                            83         3  Parent/parent-in-law
                           980         4  Brother/sister/step/adopted/fost
                                          er
                           277         5  Other relative
                            67         6  Other non-relative
                        35,495        .a  Not applicable
                            23        .b  Refusal
                            14        .c  Don't know
                            69        .d  No answer

-----------------------------------------------------------------------------------
v212                          Sixth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa6

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  37,998/39,325

            tabulation:  Freq.   Numeric  Label
                             9         1  Husband/wife/partner
                           706         2  Son/daughter/step/adopted/foster
                            23         3  Parent/parent-in-law
                           385         4  Brother/sister/step/adopted/fost
                                          er
                           177         5  Other relative
                            27         6  Other non-relative
                        37,896        .a  Not applicable
                             9        .b  Refusal
                             2        .c  Don't know
                            91        .d  No answer

-----------------------------------------------------------------------------------
v213                        Seventh person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa7

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  2,097/39,325
       unique mv codes:  4                       missing .*:  36,767/39,325

            tabulation:  Freq.   Numeric  Label
                             3         1  Husband/wife/partner
                           219         2  Son/daughter/step/adopted/foster
                             5         3  Parent/parent-in-law
                           139         4  Brother/sister/step/adopted/fost
                                          er
                            80         5  Other relative
                            15         6  Other non-relative
                         2,097         .  
                        36,666        .a  Not applicable
                             7        .b  Refusal
                            94        .d  No answer

-----------------------------------------------------------------------------------
v214                         Eighth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa8

                 range:  [2,6]                        units:  1
         unique values:  4                        missing .:  6,972/39,325
       unique mv codes:  4                       missing .*:  32,184/39,325

            tabulation:  Freq.   Numeric  Label
                            76         2  Son/daughter/step/adopted/foster
                            61         4  Brother/sister/step/adopted/fost
                                          er
                            26         5  Other relative
                             6         6  Other non-relative
                         6,972         .  
                        32,084        .a  Not applicable
                             4        .b  Refusal
                            96        .d  No answer

-----------------------------------------------------------------------------------
v215                          Ninth person in household: relationship to respondent
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshipa9

                 range:  [2,6]                        units:  1
         unique values:  4                        missing .:  12,820/39,325
       unique mv codes:  4                       missing .*:  26,433/39,325

            tabulation:  Freq.   Numeric  Label
                            33         2  Son/daughter/step/adopted/foster
                            26         4  Brother/sister/step/adopted/fost
                                          er
                             9         5  Other relative
                             4         6  Other non-relative
                        12,820         .  
                        26,344        .a  Not applicable
                             1        .b  Refusal
                            88        .d  No answer

-----------------------------------------------------------------------------------
v216                   Relationship with husband/wife/partner currently living with
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rshpsts

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  16,249/39,325

            tabulation:  Freq.   Numeric  Label
                        18,719         1  Legally married
                           231         2  In a legally registered civil
                                          union
                         3,173         3  Living with my partner - not
                                          legally recognised
                           893         4  Living with my partner - legally
                                          recognised
                             6         5  Legally separated
                            54         6  Legally divorced/civil union
                                          dissolved
                        16,008        .a  Not applicable
                            14        .b  Refusal
                            27        .c  Don't know
                           200        .d  No answer

-----------------------------------------------------------------------------------
v217                                                     Doing last 7 days: retired
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rtrd

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        28,737         0  Not marked
                        10,588         1  Marked

-----------------------------------------------------------------------------------
v218                                             Partner doing last 7 days: retired
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  rtrdp

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        33,553         0  Not marked
                         5,772         1  Marked

-----------------------------------------------------------------------------------
v219                  Take part in social activities compared to others of same age
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  sclact

                 range:  [1,5]                        units:  1
         unique values:  5                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  565/39,325

            tabulation:  Freq.   Numeric  Label
                         4,671         1  Much less than most
                        10,450         2  Less than most
                        17,270         3  About the same
                         5,319         4  More than most
                         1,050         5  Much more than most
                            14        .a  Refusal
                           542        .b  Don't know
                             9        .c  No answer

-----------------------------------------------------------------------------------
v220                  How often socially meet with friends, relatives or colleagues
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  sclmeet

                 range:  [1,7]                        units:  1
         unique values:  7                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  572/39,325

            tabulation:  Freq.   Numeric  Label
                           756         1  Never
                         3,160         2  Less than once a month
                         3,978         3  Once a month
                         8,102         4  Several times a month
                         7,165         5  Once a week
                        10,618         6  Several times a week
                         4,974         7  Every day
                            11        .a  Refusal
                           553        .b  Don't know
                             8        .c  No answer

-----------------------------------------------------------------------------------
v221                                                 Signed petition last 12 months
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  sgnptit

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  148/39,325

            tabulation:  Freq.   Numeric  Label
                         9,755         1  Yes
                        29,422         2  No
                             7        .a  Refusal
                           134        .b  Don't know
                             7        .c  No answer

-----------------------------------------------------------------------------------
v222                                        Sleep was restless, how often past week
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  slprl

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  175/39,325

            tabulation:  Freq.   Numeric  Label
                        17,536         1  None or almost none of the time
                        15,069         2  Some of the time
                         4,558         3  Most of the time
                         1,987         4  All or almost all of the time
                            45        .a  Refusal
                           113        .b  Don't know
                            17        .c  No answer

-----------------------------------------------------------------------------------
v223                          How satisfied with the way democracy works in country
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  stfdem, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,153/39,325

              examples:  3     
                         5     
                         6     
                         8     

-----------------------------------------------------------------------------------
v224                         How satisfied with present state of economy in country
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  stfeco, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  635/39,325

              examples:  3     
                         4     
                         6     
                         7     

-----------------------------------------------------------------------------------
v225                                         State of education in country nowadays
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  stfedu, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,649/39,325

              examples:  4     
                         5     
                         7     
                         8     

-----------------------------------------------------------------------------------
v226                                     How satisfied with the national government
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  stfgov, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  1,154/39,325

              examples:  2     
                         4     
                         5     
                         7     

-----------------------------------------------------------------------------------
v227                                   State of health services in country nowadays
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  stfhlth, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  287/39,325

              examples:  3     
                         5     
                         7     
                         8     

-----------------------------------------------------------------------------------
v228                                      Day of month, supplementary questionnaire
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  supqdd, but 31 nonmissing values are not labeled

                 range:  [1,31]                       units:  1
         unique values:  31                       missing .:  0/39,325
       unique mv codes:  1                       missing .*:  286/39,325

              examples:  7     
                         13    
                         19    
                         25    

-----------------------------------------------------------------------------------
v229                                             Month, supplementary questionnaire
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  supqmm, but 12 nonmissing values are not labeled

                 range:  [1,12]                       units:  1
         unique values:  12                       missing .:  0/39,325
       unique mv codes:  1                       missing .*:  282/39,325

              examples:  4     
                         9     
                         10    
                         11    

-----------------------------------------------------------------------------------
v230                                              Year, supplementary questionnaire
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  supqyr, but 2 nonmissing values are not labeled

                 range:  [2014,2015]                  units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  1                       missing .*:  282/39,325

            tabulation:  Freq.   Numeric  Label
                        22,686      2014  
                        16,357      2015  
                           282        .a  Not available

-----------------------------------------------------------------------------------
v231                                      What type of organisation work/worked for
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  tporgwk

                 range:  [1,6]                        units:  1
         unique values:  6                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  3,496/39,325

            tabulation:  Freq.   Numeric  Label
                         3,587         1  Central or local government
                         4,667         2  Other public sector (such as
                                          education and health)
                         3,218         3  A state owned enterprise
                        20,143         4  A private firm
                         3,321         5  Self employed
                           893         6  Other
                         3,113        .a  Not applicable
                            48        .b  Refusal
                           298        .c  Don't know
                            37        .d  No answer

-----------------------------------------------------------------------------------
v232                                               Trust in the European Parliament
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  trstep, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  3,232/39,325

              examples:  2     
                         4     
                         5     
                         7     

-----------------------------------------------------------------------------------
v233                                                      Trust in the legal system
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  trstlgl, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  737/39,325

              examples:  3     
                         5     
                         7     
                         8     

-----------------------------------------------------------------------------------
v234                                                            Trust in the police
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  trstplc, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  285/39,325

              examples:  4     
                         6     
                         7     
                         8     

-----------------------------------------------------------------------------------
v235                                                           Trust in politicians
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  trstplt, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  500/39,325

              examples:  1     
                         3     
                         4     
                         6     

-----------------------------------------------------------------------------------
v236                                                  Trust in country's parliament
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  trstprl, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  791/39,325

              examples:  2     
                         4     
                         5     
                         7     

-----------------------------------------------------------------------------------
v237                                                     Trust in political parties
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  trstprt, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  701/39,325

              examples:  1     
                         3     
                         5     
                         6     

-----------------------------------------------------------------------------------
v238                                                    Trust in the United Nations
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  trstun, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  3,144/39,325

              examples:  3     
                         5     
                         6     
                         8     

-----------------------------------------------------------------------------------
v239                  TV watching, news/politics/current affairs on average weekday
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  tvpol

                 range:  [0,7]                        units:  1
         unique values:  8                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  2,153/39,325

            tabulation:  Freq.   Numeric  Label
                         3,376         0  No time at all
                        11,583         1  Less than 0,5 hour
                        13,082         2  0,5 hour to 1 hour
                         4,869         3  More than 1 hour, up to 1,5
                                          hours
                         2,123         4  More than 1,5 hours, up to 2
                                          hours
                           979         5  More than 2 hours, up to 2,5
                                          hours
                           518         6  More than 2,5 hours, up to 3
                                          hours
                           642         7  More than 3 hours
                         2,066        .a  Not applicable
                             1        .b  Refusal
                            79        .c  Don't know
                             7        .d  No answer

-----------------------------------------------------------------------------------
v240                                     TV watching, total time on average weekday
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  tvtot

                 range:  [0,7]                        units:  1
         unique values:  8                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  71/39,325

            tabulation:  Freq.   Numeric  Label
                         2,066         0  No time at all
                         2,476         1  Less than 0,5 hour
                         5,471         2  0,5 hour to 1 hour
                         5,544         3  More than 1 hour, up to 1,5
                                          hours
                         6,531         4  More than 1,5 hours, up to 2
                                          hours
                         5,248         5  More than 2 hours, up to 2,5
                                          hours
                         4,509         6  More than 2,5 hours, up to 3
                                          hours
                         7,409         7  More than 3 hours
                             3        .a  Refusal
                            66        .b  Don't know
                             2        .c  No answer

-----------------------------------------------------------------------------------
v241           Any period of unemployment and work seeking lasted 12 months or more
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  uemp12m

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  28,261/39,325

            tabulation:  Freq.   Numeric  Label
                         4,985         1  Yes
                         6,079         2  No
                        28,197        .a  Not applicable
                             2        .b  Refusal
                            49        .c  Don't know
                            13        .d  No answer

-----------------------------------------------------------------------------------
v242           Ever unemployed and seeking work for a period more than three months
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  uemp3m

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  168/39,325

            tabulation:  Freq.   Numeric  Label
                        11,117         1  Yes
                        28,040         2  No
                            65        .a  Refusal
                            92        .b  Don't know
                            11        .c  No answer

-----------------------------------------------------------------------------------
v243                Any period of unemployment and work seeking within last 5 years
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  uemp5yr

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  28,257/39,325

            tabulation:  Freq.   Numeric  Label
                         5,238         1  Yes
                         5,830         2  No
                        28,197        .a  Not applicable
                             4        .b  Refusal
                            31        .c  Don't know
                            25        .d  No answer

-----------------------------------------------------------------------------------
v244                        Doing last 7 days: unemployed, actively looking for job
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  uempla

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        37,640         0  Not marked
                         1,685         1  Marked

-----------------------------------------------------------------------------------
v245                Partner doing last 7 days: unemployed, actively looking for job
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  uemplap

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,574         0  Not marked
                           751         1  Marked

-----------------------------------------------------------------------------------
v246                    Doing last 7 days: unemployed, not actively looking for job
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  uempli

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        38,566         0  Not marked
                           759         1  Marked

-----------------------------------------------------------------------------------
v247            Partner doing last 7 days: unemployed, not actively looking for job
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  uemplip

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.   Numeric  Label
                        39,001         0  Not marked
                           324         1  Marked

-----------------------------------------------------------------------------------
v248                                                   Voted last national election
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  vote

                 range:  [1,3]                        units:  1
         unique values:  3                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  323/39,325

            tabulation:  Freq.   Numeric  Label
                        27,276         1  Yes
                         8,311         2  No
                         3,415         3  Not eligible to vote
                            47        .a  Refusal
                           274        .b  Don't know
                             2        .c  No answer

-----------------------------------------------------------------------------------
v249                                  Allowed to decide how daily work is organised
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  wkdcorga, but 9 nonmissing values are not labeled

                 range:  [0,10]                       units:  1
         unique values:  11                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  3,511/39,325

              examples:  3     
                         7     
                         8     
                         10    I have/had complete control

-----------------------------------------------------------------------------------
v250                  Total contracted hours per week in main job overtime excluded
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  wkhct, but 107 nonmissing values are not labeled

                 range:  [0,168]                      units:  1
         unique values:  107                      missing .:  0/39,325
       unique mv codes:  4                       missing .*:  5,980/39,325

              examples:  35    
                         40    
                         40    
                         50    

-----------------------------------------------------------------------------------
v251             Total hours normally worked per week in main job overtime included
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  wkhtot, but 112 nonmissing values are not labeled

                 range:  [0,168]                      units:  1
         unique values:  112                      missing .:  0/39,325
       unique mv codes:  4                       missing .*:  5,041/39,325

              examples:  35    
                         40    
                         43    
                         56    

-----------------------------------------------------------------------------------
v252            Hours normally worked a week in main job overtime included, partner
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  wkhtotp, but 91 nonmissing values are not labeled

                 range:  [0,168]                      units:  1
         unique values:  91                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  25,683/39,325

              examples:  40    
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v253                                                Were happy, how often past week
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  wrhpp

                 range:  [1,4]                        units:  1
         unique values:  4                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  365/39,325

            tabulation:  Freq.   Numeric  Label
                         1,762         1  None or almost none of the time
                         8,429         2  Some of the time
                        18,533         3  Most of the time
                        10,236         4  All or almost all of the time
                            54        .a  Refusal
                           283        .b  Don't know
                            28        .c  No answer

-----------------------------------------------------------------------------------
v254          Paid work in another country, period more than 6 months last 10 years
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  wrkac6m

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  3,221/39,325

            tabulation:  Freq.   Numeric  Label
                         2,226         1  Yes
                        33,878         2  No
                         3,113        .a  Not applicable
                            11        .b  Refusal
                            50        .c  Don't know
                            47        .d  No answer

-----------------------------------------------------------------------------------
v255                              Employment contract unlimited or limited duration
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  wrkctra

                 range:  [1,3]                        units:  1
         unique values:  3                        missing .:  0/39,325
       unique mv codes:  4                       missing .*:  7,688/39,325

            tabulation:  Freq.   Numeric  Label
                        23,981         1  Unlimited
                         4,760         2  Limited
                         2,896         3  No contract
                         7,272        .a  Not applicable
                            45        .b  Refusal
                           312        .c  Don't know
                            59        .d  No answer

-----------------------------------------------------------------------------------
v256                   Worked in another organisation or association last 12 months
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  wrkorg

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  1,195/39,325
       unique mv codes:  4                       missing .*:  96/39,325

            tabulation:  Freq.   Numeric  Label
                         6,622         1  Yes
                        31,412         2  No
                         1,195         .  
                             8        .a  Refusal
                            82        .b  Don't know
                             6        .c  No answer

-----------------------------------------------------------------------------------
v257                       Worked in political party or action group last 12 months
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  wrkprty

                 range:  [1,2]                        units:  1
         unique values:  2                        missing .:  0/39,325
       unique mv codes:  3                       missing .*:  75/39,325

            tabulation:  Freq.   Numeric  Label
                         1,765         1  Yes
                        37,485         2  No
                            11        .a  Refusal
                            54        .b  Don't know
                            10        .c  No answer

-----------------------------------------------------------------------------------
v258                                                                  Year of birth
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn, but 90 nonmissing values are not labeled

                 range:  [1900,2000]                  units:  1
         unique values:  90                       missing .:  0/39,325
       unique mv codes:  3                       missing .*:  97/39,325

              examples:  1947  
                         1959  
                         1971  
                         1984  

-----------------------------------------------------------------------------------
v259                                     Year of birth of tenth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn10, but 15 nonmissing values are not labeled

                 range:  [1989,2015]                  units:  1
         unique values:  15                       missing .:  14,320/39,325
       unique mv codes:  5                       missing .*:  24,962/39,325

              examples:  .     
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v260                                  Year of birth of eleventh person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn11, but 11 nonmissing values are not labeled

                 range:  [1994,2015]                  units:  1
         unique values:  11                       missing .:  18,264/39,325
       unique mv codes:  4                       missing .*:  21,038/39,325

              examples:  .     
                         .     
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v261                                   Year of birth of twelfth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn12, but 8 nonmissing values are not labeled

                 range:  [1994,2014]                  units:  1
         unique values:  8                        missing .:  21,843/39,325
       unique mv codes:  4                       missing .*:  17,473/39,325

            tabulation:  Freq.   Numeric  Label
                             1      1994  
                             1      2000  
                             1      2009  
                             2      2010  
                             1      2011  
                             1      2012  
                             1      2013  
                             1      2014  
                        21,843         .  
                        17,382        .a  Not applicable
                             1        .c  Don't know
                            90        .d  No answer

-----------------------------------------------------------------------------------
v262                                Year of birth of thirteenth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn13, but 1 nonmissing value is not labeled

                 range:  [2012,2012]                  units:  1
         unique values:  1                        missing .:  35,393/39,325
       unique mv codes:  3                       missing .*:  3,931/39,325

            tabulation:  Freq.   Numeric  Label
                             1      2012  
                        35,393         .  
                         3,930        .a  Not applicable
                             1        .d  No answer

-----------------------------------------------------------------------------------
v263                                    Year of birth of second person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn2, but 104 nonmissing values are not labeled

                 range:  [1900,2014]                  units:  1
         unique values:  104                      missing .:  0/39,325
       unique mv codes:  4                       missing .*:  8,690/39,325

              examples:  1952  
                         1965  
                         1977  
                         .a    Not applicable

-----------------------------------------------------------------------------------
v264                                     Year of birth of third person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn3, but 99 nonmissing values are not labeled

                 range:  [1902,2015]                  units:  1
         unique values:  99                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  22,269/39,325

              examples:  1994  
                         2011  
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v265                                    Year of birth of fourth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn4, but 92 nonmissing values are not labeled

                 range:  [1920,2015]                  units:  1
         unique values:  92                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  29,218/39,325

              examples:  2008  
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v266                                     Year of birth of fifth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn5, but 79 nonmissing values are not labeled

                 range:  [1921,2015]                  units:  1
         unique values:  79                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  35,664/39,325

              examples:  .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v267                                     Year of birth of sixth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn6, but 67 nonmissing values are not labeled

                 range:  [1927,2015]                  units:  1
         unique values:  67                       missing .:  0/39,325
       unique mv codes:  4                       missing .*:  38,036/39,325

              examples:  .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v268                                   Year of birth of seventh person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn7, but 42 nonmissing values are not labeled

                 range:  [1925,2015]                  units:  1
         unique values:  42                       missing .:  2,097/39,325
       unique mv codes:  5                       missing .*:  36,785/39,325

              examples:  .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v269                                    Year of birth of eighth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn8, but 30 nonmissing values are not labeled

                 range:  [1935,2015]                  units:  1
         unique values:  30                       missing .:  6,972/39,325
       unique mv codes:  5                       missing .*:  32,190/39,325

              examples:  .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
v270                                     Year of birth of ninth person in household
-----------------------------------------------------------------------------------

                  type:  numeric (double)
                 label:  yrbrn9, but 25 nonmissing values are not labeled

                 range:  [1935,2015]                  units:  1
         unique values:  25                       missing .:  12,820/39,325
       unique mv codes:  5                       missing .*:  26,438/39,325

              examples:  .     
                         .a    Not applicable
                         .a    Not applicable
                         .a    Not applicable

-----------------------------------------------------------------------------------
cntry                                                                       Country
-----------------------------------------------------------------------------------

                  type:  string (str2)

         unique values:  21                       missing "":  0/39,325

              examples:  "DE"
                         "FI"
                         "IE"
                         "NL"

-----------------------------------------------------------------------------------
id                                                                      (unlabeled)
-----------------------------------------------------------------------------------

                  type:  numeric (float)

                 range:  [1,39325]                    units:  1
         unique values:  39,325                   missing .:  0/39,325

                  mean:     19663
              std. dev:   11352.3

           percentiles:        10%       25%       50%       75%       90%
                              3933      9832     19663     29494     35393

-----------------------------------------------------------------------------------
satisfied                                                               (unlabeled)
-----------------------------------------------------------------------------------

                  type:  numeric (float)

                 range:  [0,1]                        units:  1
         unique values:  2                        missing .:  0/39,325

            tabulation:  Freq.  Value
                        18,800  0
                        20,525  1
"""

# %%
splitted = text.split("type:")

# %%
list_of_dict = []
for i, t in enumerate(splitted[:271]):
    if i == 0:
        continue
    t = t[:t.find("-------")]
    t = "type:" + t
    temp = re.split("\n+|[ \t]{6,}", t)
    temp = [line for line in temp if line.find(':') > 0]
    
    my_dict = {}
    for attribute in temp:
        k, v = attribute.split(':')
        my_dict[k] = v.strip()
    my_dict['name'] = 'v' + str(i)
    list_of_dict.append(my_dict)

# %%
lookup_table = pd.DataFrame(list_of_dict)

# %%
lookup_table.drop(columns=["examples", "tabulation", "percentiles"])
# Out:
#                  type                                             label  \
# 0    numeric (double)  actrolg, but 9 nonmissing values are not labeled
# 1    numeric (double)                                           aesfdrk
# 2    numeric (double)    agea, but 90 nonmissing values are not labeled
# 3    numeric (double)                                           anctry1
# 4    numeric (double)                                           anctry2
# ..                ...                                               ...
# 265  numeric (double)  yrbrn5, but 79 nonmissing values are not labeled
# 266  numeric (double)  yrbrn6, but 67 nonmissing values are not labeled
# 267  numeric (double)  yrbrn7, but 42 nonmissing values are not labeled
# 268  numeric (double)  yrbrn8, but 30 nonmissing values are not labeled
# 269  numeric (double)  yrbrn9, but 25 nonmissing values are not labeled
#
#               range units unique values      missing . unique mv codes  \
# ...
